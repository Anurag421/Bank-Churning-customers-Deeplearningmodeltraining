# %%
import keras as ks

# %%
import torch as tr

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/bank.csv")

# %%
df.head(5)
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
import matplotlib.pyplot as plt

# %%
x= df.iloc[:,1:10]
y =df.iloc[:,11]

# %%
# As gender and country are object data type then we need to create them into the dummy dataset
country=pd.get_dummies(x["country"], drop_first=True)
gender=pd.get_dummies(x['gender'], drop_first=True)

# %%
x=pd.concat([x,country,gender],axis=1)
x
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619   France  Female   42       2       0.00                1
# 1              608    Spain  Female   41       1   83807.86                1
# 2              502   France  Female   42       8  159660.80                3
# 3              699   France  Female   39       1       0.00                2
# 4              850    Spain  Female   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771   France    Male   39       5       0.00                2
# 9996           516   France    Male   35      10   57369.61                1
# 9997           709   France  Female   36       7       0.00                1
# 9998           772  Germany    Male   42       3   75075.31                2
# 9999           792   France  Female   28       4  130142.79                1
#
# ...

# %%
#Drop Unnecessory columns ( country and gender )
x=x.drop(['country','gender'], axis=1)

# %%
x
# Out:
#       credit_score  age  tenure    balance  products_number  credit_card  \
# 0              619   42       2       0.00                1            1
# 1              608   41       1   83807.86                1            0
# 2              502   42       8  159660.80                3            1
# 3              699   39       1       0.00                2            0
# 4              850   43       2  125510.82                1            1
# ...            ...  ...     ...        ...              ...          ...
# 9995           771   39       5       0.00                2            1
# 9996           516   35      10   57369.61                1            1
# 9997           709   36       7       0.00                1            0
# 9998           772   42       3   75075.31                2            1
# 9999           792   28       4  130142.79                1            1
#
#       active_member  Germany  Spain  Male
# 0                 1        0      0     0
# ...

# %%
#splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
 #feature Scaling
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train =sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
#part 2- Now we will be making ANN

# %%
#importing the keras libraries and package

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU, ELU
from keras.layers import Dropout

# %% [markdown]
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
# from tensorflow.keras.callbacks import EarlyStopping
# import tensorflow as tf
# samples = 500
# X_train_sc = tf.random.normal((samples, 81))
# y_train = tf.random.uniform((samples, ), maxval=2, dtype=tf.int32)
# # Creating our model's structure
# model = Sequential()
# model.add(Dense(64, activation='relu', input_shape=(81,)))
# model.add(Dropout(0.18))
# model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.15))
# model.add(Dense(1, activation='sigmoid'))
# es = EarlyStopping(monitor='val_loss', patience=5)
# # Compiling the model
# model.compile(loss='bce',
#               optimizer='adam',
#               metrics=['binary_accuracy'])
# # Fitting the model
# history = model.fit(X_train_sc,
#                     y_train,
#                     batch_size = 32,
#                     epochs = 2,
#                     verbose = 0)

# %% [markdown]
# sequential library is responsible for
# creating this typ of neural network
#
# form creating hidden layers we need desnse library
#
# optimizer libraries
#
# Dropout is your regulerization parameter
# when every our neural networks are fualty

# %%
#initialising the ANN ( sequential library)
classifier = Sequential()

# %%
#adding the input layers and the first hidden layer, using dense to create first hidden layer
classifier.add(Dense(units = 5, kernel_initializer ='he_uniform', activation='relu', input_dim=10))

# %%
#to check total number of inputs we need to take in input dim
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   credit_score     10000 non-null  int64
#  1   age              10000 non-null  int64
#  2   tenure           10000 non-null  int64
#  3   balance          10000 non-null  float64
#  4   products_number  10000 non-null  int64
#  5   credit_card      10000 non-null  int64
#  6   active_member    10000 non-null  int64
#  7   Germany          10000 non-null  uint8
#  8   Spain            10000 non-null  uint8
#  9   Male             10000 non-null  uint8
# dtypes: float64(1), int64(6), uint8(3)
# memory usage: 576.3 KB

# %%
#adding the second hidding layer
classifier.add(Dense(units = 5, kernel_initializer ='he_uniform', activation='relu' ))

# %%
classifier.add(Dropout(0.3))

# %% [markdown]
# units for hidden layer no. of neurons in the first layer selection
#
# kernel_initilizer for weight initilization
# activation -Relu for using adding activation function to the equation

# %%
#Adding output layer
classifier.add(Dense(units=1, kernel_initializer ='glorot_uniform', activation ='sigmoid'))

# %% [markdown]
# as we know answer in last layer would be one means the customers are going to chrun (1) represented by 1 only so want 1 so we are using sigmoid function in last layer
#
# in initail two layer we are taking relu or we can take leaky relu to avoid vanishing of gradient function but in last layer as we want so far calculation in both layer in the form of 0 or 1 so we rae snusing the sigmoid fution

# %%
#compiling the ANN
classifier.compile(optimizer = 'adam' , loss = 'binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# While compiling we are going to define waht kind of opitmizer need to be used what type of loss function we are going to use and what matrics we are looking for
#
# As adamax is best and mostly used loss function
# as we have binary output so we are looking for binary_crossentropy
#
# if we have more than one category we will be looking for the category_crossentropy

# %%
#Fitting the ANN to the training set
model_history = classifier.fit(x_train, y_train , validation_split = 0.33, batch_size = 10, epochs= 50)
# Out:
# Epoch 1/50
# 536/536 [==============================] - 4s 6ms/step - loss: 0.6196 - accuracy: 0.7936 - val_loss: 0.5612 - val_accuracy: 0.8527
# Epoch 2/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.5262 - accuracy: 0.8403 - val_loss: 0.4933 - val_accuracy: 0.8478
# Epoch 3/50
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4755 - accuracy: 0.8444 - val_loss: 0.4551 - val_accuracy: 0.8440
# Epoch 4/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4491 - accuracy: 0.8429 - val_loss: 0.4318 - val_accuracy: 0.8470
# Epoch 5/50
# 536/536 [==============================] - 5s 9ms/step - loss: 0.4317 - accuracy: 0.8461 - val_loss: 0.4165 - val_accuracy: 0.8459
# Epoch 6/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4279 - accuracy: 0.8399 - val_loss: 0.4082 - val_accuracy: 0.8478
# Epoch 7/50
# ...

# %%
#Part -3 Making the prediction and evaluating the model

# %%
#Predicting the test set result
y_pred=classifier.predict(x_test)
y_pred=(y_pred>0.5)

# %%
#making the confusion matrics
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred)
cm

# %%
#calculate the accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred )
